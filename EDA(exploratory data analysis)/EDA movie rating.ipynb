# %%
import pandas as pd
movies= pd.read_csv(r"C:\Users\pvjay\Downloads\Movie-Rating.csv")
movies
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
len(movies)
# Out:
# 559

# %%
movies.shape
# Out:
# (559, 6)

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Film                       559 non-null    object
#  1   Genre                      559 non-null    object
#  2   Rotten Tomatoes Ratings %  559 non-null    int64
#  3   Audience Ratings %         559 non-null    int64
#  4   Budget (million $)         559 non-null    int64
#  5   Year of release            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns = ['Film', 'Genre','CriticRating','AudianceRating','BudgetMillions','Year']

# %%
movies.head(1)
# Out:
#                     Film   Genre  CriticRating  AudianceRating  \
# 0  (500) Days of Summer   Comedy            87              81
#
#    BudgetMillions  Year
# 0               8  2009

# %%
movies.describe()
# Out:
#        CriticRating  AudianceRating  BudgetMillions         Year
# count    559.000000      559.000000      559.000000   559.000000
# mean      47.309481       58.744186       50.236136  2009.152057
# std       26.413091       16.826887       48.731817     1.362632
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    object
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudianceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.Film = movies.Film.astype('category')

# %%
movies.Film
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: category
# Categories (559, object): ['(500) Days of Summer ', '10,000 B.C.', '12 Rounds ', '127 Hours', ..., 'Youth in Revolt', 'Zodiac', 'Zombieland ', 'Zookeeper']

# %%
movies.Genre = movies.Genre.astype('category')
movies.Year = movies.Year.astype('category')

# %%
movies.Genre
# Out:
# 0         Comedy
# 1      Adventure
# 2         Action
# 3      Adventure
# 4         Comedy
#          ...
# 554       Comedy
# 555       Comedy
# 556     Thriller
# 557       Action
# 558       Comedy
# Name: Genre, Length: 559, dtype: category
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %%
movies.Year
# Out:
# 0      2009
# 1      2008
# 2      2009
# 3      2010
# 4      2009
#        ...
# 554    2011
# 555    2009
# 556    2007
# 557    2009
# 558    2011
# Name: Year, Length: 559, dtype: category
# Categories (5, int64): [2007, 2008, 2009, 2010, 2011]

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   CriticRating    559 non-null    int64
#  3   AudianceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
movies.describe()
# Out:
#        CriticRating  AudianceRating  BudgetMillions
# count    559.000000      559.000000      559.000000
# mean      47.309481       58.744186       50.236136
# std       26.413091       16.826887       48.731817
# min        0.000000        0.000000        0.000000
# 25%       25.000000       47.000000       20.000000
# 50%       46.000000       58.000000       35.000000
# 75%       70.000000       72.000000       65.000000
# max       97.000000       96.000000      300.000000

# %%
movies.notnull()
# Out:
#      Film  Genre  CriticRating  AudianceRating  BudgetMillions  Year
# 0    True   True          True            True            True  True
# 1    True   True          True            True            True  True
# 2    True   True          True            True            True  True
# 3    True   True          True            True            True  True
# 4    True   True          True            True            True  True
# ..    ...    ...           ...             ...             ...   ...
# 554  True   True          True            True            True  True
# 555  True   True          True            True            True  True
# 556  True   True          True            True            True  True
# 557  True   True          True            True            True  True
# 558  True   True          True            True            True  True
#
# [559 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
j=sns.jointplot(data=movies, x='CriticRating', y='AudianceRating',kind='scatter')

# %%
j=sns.jointplot(data=movies, x='CriticRating', y='AudianceRating',kind='kde')

# %%
j=sns.jointplot(data=movies, x='CriticRating', y='AudianceRating',kind='hex')

# %%
sns.set_style('darkgrid')
j=sns.jointplot(data=movies, x='CriticRating', y='AudianceRating',kind='reg')

# %%
m1 = sns.histplot(movies.AudianceRating)

# %%
m1 = sns.histplot(movies.AudianceRating, bins=20, color='red', kde=False)

# %%
sns.set_style('ticks')
m1 = sns.histplot(movies.AudianceRating, bins=20, color='red', kde=True)

# %%
plt.hist(movies[movies.Genre == 'Drama'].BudgetMillions) #ploting histogram for Drama genre
plt.show()

# %%
plt.hist(movies[movies.Genre == 'Comedy'].BudgetMillions) #ploting histogram for Comedy genre
# Out:
# (array([39., 55., 37., 17., 18.,  4.,  1.,  0.,  0.,  1.]),
#  array([  0. ,  17.5,  35. ,  52.5,  70. ,  87.5, 105. , 122.5, 140. ,
#         157.5, 175. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(movies[movies.Genre == 'Action'].BudgetMillions) #ploting histogram for Action genre
plt.hist(movies[movies.Genre == 'Thriller'].BudgetMillions) #ploting histogram for Thriller genre
plt.hist(movies[movies.Genre == 'Drama'].BudgetMillions) #ploting histogram for Drama genre
# Out:
# (array([25., 40., 18.,  8.,  6.,  2.,  1.,  0.,  0.,  1.]),
#  array([  0.,  15.,  30.,  45.,  60.,  75.,  90., 105., 120., 135., 150.]),
#  <BarContainer object of 10 artists>)

# %%
# Below plots are stacked histogram becuase overlaped

plt.hist(movies[movies.Genre == 'Action'].BudgetMillions, bins = 20, color = 'red')
plt.hist(movies[movies.Genre == 'Thriller'].BudgetMillions, bins = 20, color = 'green')
plt.hist(movies[movies.Genre == 'Drama'].BudgetMillions, bins = 20, color = 'blue')
#plt.legend()
#plt.show()
# Out:
# (array([14., 11., 27., 13., 13.,  5.,  5.,  3.,  4.,  2.,  2.,  0.,  0.,
#          1.,  0.,  0.,  0.,  0.,  0.,  1.]),
#  array([  0. ,   7.5,  15. ,  22.5,  30. ,  37.5,  45. ,  52.5,  60. ,
#          67.5,  75. ,  82.5,  90. ,  97.5, 105. , 112.5, 120. , 127.5,
#         135. , 142.5, 150. ]),
#  <BarContainer object of 20 artists>)

# %%
plt.hist([movies[movies.Genre == 'Action'].BudgetMillions,\
          movies[movies.Genre == 'Drama'].BudgetMillions, \
          movies[movies.Genre == 'Thriller'].BudgetMillions, \
          movies[movies.Genre == 'Comedy'].BudgetMillions],
         bins = 20, stacked = True)
plt.show()

# %%
# if you have 100 categories you cannot copy & paste all the things

for gen in movies.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
vis1 = sns.lmplot(data=movies, x='CriticRating', y='AudianceRating',\
                 fit_reg=False, hue = 'Genre')

# %%
vis1 = sns.lmplot(data=movies, x='CriticRating', y='AudianceRating',fit_reg=False, hue = 'Genre', height = 5,aspect=1)

# %%
k1 = sns.kdeplot(
    data=movies,
    x='CriticRating',
    y='AudianceRating',
    hue='Genre',
    fill=False,
    cmap="blue"
)
plt.show()

# %%
#Box plots - 

w = sns.boxplot(data=movies, x='Genre', y = 'CriticRating',hue='Genre')

# %%
g =sns.FacetGrid (movies, row = 'Genre', col = 'Year', hue = 'Genre',height=3)
g = g.map(plt.scatter, 'CriticRating', 'AudianceRating' ) #scatterplots are mapped in facetgrid

# %%
# you can populated any type of chat. 

g =sns.FacetGrid (movies, row = 'Genre', col = 'Year', hue = 'Genre',height=2)
g = g.map(plt.hist, 'BudgetMillions') #scatterplots are mapped in facetgrid

# %%
g =sns.FacetGrid (movies, row = 'Genre', col = 'Year', hue = 'Genre')
kws = dict(s=50, linewidth=0.5,edgecolor='black')
g = g.map(plt.scatter, 'CriticRating', 'AudianceRating',**kws ) #scatterplots are mapped in facetgrid
