# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from PIL import Image #python imaging library(PIL)

# %%
img = Image.open(r"C:\Users\pvjay\Pictures\Screenshots\Screenshot 2025-02-19 163501.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1137x1015>

# %%
img = Image.open(r"C:\Users\pvjay\Pictures\Screenshots\Screenshot 2025-04-24 171437.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=596x318>
